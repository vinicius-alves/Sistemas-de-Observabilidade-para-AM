# %%
#mysql-connector-python
import mysql.connector
from tqdm.notebook import tqdm

cnx = mysql.connector.connect(user='root', password='000000000',
                              host='127.0.0.1',
                              database='mydb')
cnx.close()

# %%
import glob
import pandas as pd
pasta_prefixo = 'consumo' 
csv_files = glob.glob(pasta_prefixo + '/*/*.csv')

# %%
df = None
for arquivo in tqdm(csv_files):
    df_step= pd.read_csv(arquivo, engine = 'python')
    if df is None:
        df = df_step
    else:
        df = pd.concat([df,df_step], axis = 0 )
# Out:
#   0%|          | 0/4721 [00:00<?, ?it/s]

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv(pasta_prefixo + '/*/*.csv').compute()

# %%
df['DscDetalheMercado'] = df['DscDetalheMercado'].str.lower()

# %%
replace_dict = {
    'pis/cofins (r$)':'impostos',
    'cofins (r$)':'impostos',
    'icms (r$)':'impostos',
    'pis/pasep (r$)' : 'impostos',
    'receita energia (r$)' : 'receita',
    'energia consumida (kwh)' : 'energia consumida',
    'energia injetada (kwh)' : 'energia injetada'
}


df['DscDetalheMercado'] = df['DscDetalheMercado'].replace(replace_dict)

# %%
df= df[~df['DscDetalheMercado'].isin(['receita demanda (r$)','desconto demanda %',
 'desconto energia tusd %',
 'demanda faturada (kw)',
 'desconto energia te %',
 'demanda contratada kw',
 'receita bandeiras (r$)',
 'receita ultrapassagem demanda (r$)',
 'ultrapassagem demanda (kw)',
 'energia debitada do scee (kwh)',
 'desconto de energia compensada %',
 'energia compensada (kwh)',
 'receita energia compensada (r$)',
 'proinfa (kwh)',
 'nº dias utilizados',
 'energia te (kwh)'
 ,'energia tusd (kwh)'])]

# %%
mapeamento_concessionárias = \
{
  "Equatorial PA": "Pará",
  "Equatorial PI": "Piauí",
  "PACTO ENERGIA PR": "Paraná",
  "HIDROPAN": "Rio Grande do Sul",
  "LIGHT": "Rio de Janeiro",
  "MUXENERGIA": "Rio Grande do Sul",
  "CEBDIS": "Brasília",
  "UHENPAL": "Rio Grande do Sul",
  "RGE SUL": "Rio Grande do Sul",
  "Boa Vista": "Roraima",
  "AME": "Amazonas",
  "ENEL RJ": "Rio de Janeiro",
  "CEJAMA": "Roraima",
  "CELESC-DIS": "Santa Catarina",
  "CEMIG-D": "Minas Gerais",
  "ELETROCAR": "Rio Grande do Sul",
  "CERSUL": "Santa Catarina",
  "COCEL": "Paraná",
  "CEA": "Amapá",
  "COELBA": "Bahia",
  "CELPE": "Pernambuco",
  "ENEL CE": "Ceará",
  "COSERN": "Rio Grande do Norte",
  "CEEE-D": "Rio Grande do Sul",
  "CHESP": "Goiás",
  "CPFL Jaguari": "Rio Grande do Sul",
  "CPFL-PAULISTA": "São Paulo",
  "CPFL- PIRATININGA": "São Paulo",
  "SULGIPE": "Sergipe",
  "COOPERALIANÇA": "Paraná",
  "CERAL ANITÁPOLIS": "Santa Catarina",
  "CERAL-DIS": "Paraná",
  "CASTRO - DIS": "Paraná",
  "CERSAD DISTRIBUIDORA": "Santa Catarina",
  "CODESAM": "Santa Catarina",
  "CERTHIL": "Rio Grande do Sul",
  "CERFOX": "Rio Grande do Sul",
  "CERTEL ENERGIA": "Rio Grande do Sul",
  "CERMISSÕES": "Rio Grande do Sul",
  "CERGRAL": "Santa Catarina",
  "CERPALO": "Santa Catarina",
  "CEGERO": "Santa Catarina",
  "CERGAPA": "Pará",
  "CEPRAG": "Santa Catarina",
  "CERGAL": "Santa Catarina",
  "CELETRO": "Rio Grande do Sul",
  "CERIS": "São Paulo",
  "CEDRAP": "São Paulo",
  "CERBRANORTE": "Santa Catarina",
  "CETRIL": "São Paulo",
  "CEMIRIM": "São Paulo",
  "CERRP": "São Paulo",
  "CERCOS": "Sergipe",
  "CERNHE": "São Paulo",
  "CEDRI": "São Paulo",
  "COOPERMILA": "Santa Catarina",
  "CERCI": "Rio de Janeiro",
  "CERPRO": "São Paulo",
  "CERAL ARARUAMA": "Rio de Janeiro",
  "CERIPA": "São Paulo",
  "CERES": "Rio de Janeiro",
  "Diretoria": "São Paulo",
  "CERTREL": "Santa Catarina",
  "CERVAM": "São Paulo",
  "CEREJ": "Santa Catarina",
  "COOPERCOCAL": "Santa Catarina",
  "CERMOFUL": "Santa Catarina",
  "COOPERA": "Santa Catarina",
  "COOPERNORTE": "Rio Grande do Sul",
  "COOPERSUL": "Rio Grande do Sul",
  "CERILUZ": "Rio Grande do Sul",
  "CERTAJA": "Rio Grande do Sul",
  "COORSEL": "Santa Catarina",
  "COOPERLUZ": "Rio Grande do Sul",
  "COOPERZEM": "Santa Catarina",
  "COPEL-DIS": "Paraná",
  "COPREL": "Rio Grande do Sul",
  "CRELUZ-D": "Rio Grande do Sul",
  "CRERAL": "Rio Grande do Sul",
  "DCELT": "Santa Catarina",
  "DEMEI": "Rio Grande do Sul",
  "DMED": "Minas Gerais",
  "EDP ES": "Espírito Santo",
  "EDP SP": "São Paulo",
  "ELEKTRO": "São Paulo",
  "ELETROPAULO": "São Paulo",
  "EFLUL": "Santa Catarina",
  "EFLJC": "Santa Catarina",
  "ELFSM": "Espírito Santo",
  "ELETROACRE": "Acre",
  "EMT": "Mato Grosso",
  "EMS": "Mato Grosso do Sul",
  "EMR": "Rio de Janeiro",
  "EPB": "Paraíba",
  "CERON": "Rondônia",
  "ESE": "São Paulo",
  "ESS": "São Paulo",
  "ETO": "Tocantis",
  "Equatorial AL": "Alagoas",
  "Equatorial GO": "Goiás",
  "Equatorial MA": "Maranhão",
  "Ceraçá": "Santa Catarina",
  "CERMC": "São Paulo",
  "EBO": "Paraíba",
  "ENF": "Rio de Janeiro",
  "CPFL Sul Paulista": "São Paulo",
  "CELG-D" : "Goiás",
  "RGE": "Rio Grande do Sul",
  "EMG" : "Rio de Janeiro",
  "CPFL Leste Paulista" : "São Paulo",
  "CFLO" : "São Paulo",
  "FORCEL" : "Paraná",
  "CPFL Mococa" : "São Paulo",
  "CPFL Santa Cruz" : "São Paulo",
  "CERIM": "São Paulo",
  "EDEVP": "São Paulo",
  "EEB": "São Paulo",
  "CERAÇÁ": "Santa Catarina",
  "CNEE": "São Paulo",
  "CERAL ARAPOTI": "Paraná"
}

df['Estado'] = df['SigAgenteDistribuidora'].replace(mapeamento_concessionárias)

# %%
df.head(5)
# Out:
#    _id DatGeracaoConjuntoDados  NumCNPJAgenteDistribuidora  \
# 0    1              2024-05-15               4895728000180
# 2    3              2024-05-15               4895728000180
# 4    5              2024-05-15               4895728000180
# 5    6              2024-05-15               4895728000180
# 6    7              2024-05-15               4895728000180
#
#   SigAgenteDistribuidora                         NomAgenteDistribuidora  \
# 0          Equatorial PA  EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 2          Equatorial PA  EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 4          Equatorial PA  EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 5          Equatorial PA  EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 6          Equatorial PA  EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
#
#                     NomTipoMercado DscModalidadeTarifaria  \
# 0        Sistema Isolado - Regular                   Azul
# 2          Refaturamento - Regular                  Verde
# 4      Sistema de Compensação GD I                 Branca
# 5        Sistema Isolado - Regular           Convencional
# 6  Sistema Isolado - Refaturamento           Convencional
#
#   DscSubGrupoTarifario DscClasseConsumoMercado     DscSubClasseConsumidor  \
# 0                   A4         Serviço público  Água, esgoto e saneamento
# 2                   A4               Comercial              Não se aplica
# 4                   B1             Residencial                Residencial
# 5                   B1             Residencial                Residencial
# 6                   B1             Residencial                Residencial
#
#    ... IdeAgenteAcessante  NumCNPJAgenteAcessante  NomAgenteAcessante  \
# 0  ...                  0                     NaN       Não se aplica
# 2  ...                  0                     NaN       Não se aplica
# 4  ...                  0                     NaN       Não se aplica
# 5  ...                  0                     NaN       Não se aplica
# 6  ...                  0                     NaN       Não se aplica
#
#   DscPostoTarifario DscOpcaoEnergia DscClassificacao DscDetalheMercado  \
# 0        Fora ponta          CATIVO   Concessionária           receita
# 2     Não se aplica          CATIVO   Concessionária          impostos
# 4     Não se aplica          CATIVO   Concessionária          impostos
# 5     Não se aplica          CATIVO   Concessionária          impostos
# 6     Não se aplica          CATIVO   Concessionária          impostos
#
#   DatCompetencia     VlrMercado Estado
# 0     2020-04-01   10000,220000   Pará
# 2     2020-04-01  -49026,290000   Pará
# 4     2020-04-01     129,150000   Pará
# 5     2020-04-01   53264,440000   Pará
# 6     2020-04-01   -2755,380000   Pará
#
# [5 rows x 21 columns]

# %%
df['VlrMercado'] = df['VlrMercado'].str.replace(',','.', regex = False)

# %%
df['VlrMercado'] = df['VlrMercado'].astype('float64')

# %%
df_agrupado = df.groupby(['Estado','DscDetalheMercado','DatCompetencia'], as_index = False )['VlrMercado'].sum()

# %%
df_agrupado.to_parquet('consumo.parquet')

# %%
df_agrupado = pd.read_parquet('consumo.parquet')

# %%
df_agrupado['DatCompetencia']  = pd.to_datetime(df_agrupado['DatCompetencia'])

# %%
df_pivot = df_agrupado.pivot_table(index = ['Estado','DatCompetencia'], values = 'VlrMercado',columns = 'DscDetalheMercado', fill_value = 0).reset_index()

# %%
df_pivot.columns
# Out:
# Index(['Estado', 'DatCompetencia', 'energia consumida', 'energia injetada',
#        'impostos', 'número de consumidores', 'receita'],
#       dtype='object', name='DscDetalheMercado')

# %%
import plotly.express as px

# %%
for coluna in ['número de consumidores', 'energia consumida', 'energia injetada']:
    fig = px.area(df_pivot, x = 'DatCompetencia', y = coluna, color = 'Estado', title = coluna)
    fig.show()
